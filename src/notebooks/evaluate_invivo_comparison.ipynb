# %%
import numpy as np
import pandas as pd

# %%
eval_dir = '../../../results/in_vivo/plots/comparison_loss_weighting/overview'

csv_name = 'Aggregated_Avg_Results.csv' #results\in_vivo\plots\comparison_loss_weighting\overview

df_invivo_avg = pd.read_csv(f'{eval_dir}/{csv_name}')

display(df_invivo_avg)
